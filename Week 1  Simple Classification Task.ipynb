# %% [markdown]
# # We will be importing necessary python packages

# %%
get_ipython().magic('matplotlib notebook')
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Now we read fruits dataset for this simple task

# %%
fruits = pd.read_table("fruit_data_with_colors.txt")

# %%
fruits.head()
# Out:
#    fruit_label fruit_name fruit_subtype  mass  width  height  color_score
# 0            1      apple  granny_smith   192    8.4     7.3         0.55
# 1            1      apple  granny_smith   180    8.0     6.8         0.59
# 2            1      apple  granny_smith   176    7.4     7.2         0.60
# 3            2   mandarin      mandarin    86    6.2     4.7         0.80
# 4            2   mandarin      mandarin    84    6.0     4.6         0.79

# %%
fruits.shape
# Out:
# (59, 7)

# %% [raw]
# # simplet way to get unique fruit_label and corresponding fruit name

# %%
fruits_name_dict = dict(zip(fruits.fruit_label.unique(),fruits.fruit_name.unique()))

# %%
fruits_name_dict
# Out:
# {1: 'apple', 2: 'mandarin', 3: 'orange', 4: 'lemon'}

# %% [markdown]
# # Train and Test Split

# %%
X=fruits[["mass","width","height","color_score"]]

# %%
y = fruits[["fruit_label"]]

# %%
X_train,X_test,y_train,y_test = train_test_split(X, y, random_state = 111)

# %%
# X_train

# %%
y_train.reset_index(drop=True)
# Out:
#     fruit_label
# 0             4
# 1             3
# 2             4
# 3             3
# 4             4
# 5             4
# 6             4
# 7             1
# 8             4
# 9             2
# 10            2
# 11            4
# 12            1
# 13            4
# 14            1
# 15            2
# 16            4
# 17            3
# 18            4
# 19            2
# 20            3
# 21            4
# 22            3
# 23            1
# 24            1
# 25            3
# 26            1
# 27            3
# 28            3
# 29            1
# 30            1
# 31            1
# 32            4
# 33            2
# 34            3
# 35            1
# 36            1
# 37            3
# 38            1
# 39            1
# 40            4
# 41            4
# 42            4
# 43            1

# %% [markdown]
# # Visualization and Cleansing of data

# %%
from matplotlib import cm
from pandas.plotting import scatter_matrix

# %%
cmap =  cm.get_cmap("gnuplot")

# %%
z = np.array(y_train["fruit_label"])

# %%
z
# Out:
# array([4, 3, 4, 3, 4, 4, 4, 1, 4, 2, 2, 4, 1, 4, 1, 2, 4, 3, 4, 2, 3, 4,
#        3, 1, 1, 3, 1, 3, 3, 1, 1, 1, 4, 2, 3, 1, 1, 3, 1, 1, 4, 4, 4, 1],
#       dtype=int64)

# %%
colors = np.array(["red", "green","yellow","blue"])

# %%
colors
# Out:
# array(['red', 'green', 'yellow', 'blue'], dtype='<U6')

# %%
colors[z]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-41-0fa4977f67dd> in <module>
# ----> 1 colors[z]
#
# IndexError: index 4 is out of bounds for axis 0 with size 4

# %%
scatter = scatter_matrix(X_train, c= y_train["fruit_label"], marker = 'o', s=40, hist_kwds={'bins':15}, figsize=(10,10), cmap=cmap)
# Out:
# <img src="data:image/png;base64,..." width="1000">
